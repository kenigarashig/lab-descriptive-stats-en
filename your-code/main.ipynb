# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
df_t=pd.read_csv("C:/Users/igara/Ironhack Bootcamp/Bootcamp ironhack week4/lab-descriptive-stats-en-main/your-code/Temp_States.csv")

# %% [markdown]
# #### Print `temp`

# %%
df_t
# Out:
#          City     State  Temperature
# 0         NYC  New York    19.444444
# 1      Albany  New York     9.444444
# 2     Buffalo  New York     3.333333
# 3    Hartford  New York    17.222222
# 4  Bridgeport  New York    14.444444
# 5      Treton  New York    22.222222
# 6      Newark  New York    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
String,String,Float

# %% [markdown]
# #### Select the rows where state is New York

# %%
ny=df_t[df_t["State"]=="New York"]
ny
# Out:
#          City     State  Temperature
# 0         NYC  New York    19.444444
# 1      Albany  New York     9.444444
# 2     Buffalo  New York     3.333333
# 3    Hartford  New York    17.222222
# 4  Bridgeport  New York    14.444444
# 5      Treton  New York    22.222222
# 6      Newark  New York    20.000000

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
at=ny["Temperature"].mean()
at
# Out:
# 15.15873015873016

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
ta=ny[ny["Temperature"]>15]
ta
# Out:
#        City     State  Temperature
# 0       NYC  New York    19.444444
# 3  Hartford  New York    17.222222
# 5    Treton  New York    22.222222
# 6    Newark  New York    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
ta2=ny.drop("State",axis=1)
ta2_cit=ta2[ta2["Temperature"]>15]
ta2_cit
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
ta2_ran=ta2[(ta2["Temperature"]>15) & (ta2["Temperature"]<20)]
ta2_ran
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %%
df_t['State'].value_counts()
# Out:
# State
# New York    7
# Name: count, dtype: int64

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
df_t["Temperature"].mean()
# Out:
# 15.15873015873016

# %%
df_t["Temperature"].std()
# Out:
# 6.695264939070775

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
employee=pd.read_csv("C:/Users/igara/Ironhack Bootcamp/Bootcamp ironhack week4/lab-descriptive-stats-en-main/your-code/employee.csv")

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
sns.histplot(data=employee, x="Years", bins="auto")
plt.title("Histogram of Years")
plt.xlabel("Years of Experience")
plt.ylabel("Frequency")
plt.show()

# %%
#we ca observe that the most frequent year of experience is 1-2.5 years

# %%
# YOUR CODE HERE

# %% [markdown]
# #### What's the average salary in this company?

# %%
employee["Salary"].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
max(employee["Salary"])
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
min(employee["Salary"])
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
min_empl=employee[employee["Salary"]==30]
min_empl
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
info_dav=employee[employee["Name"]=="David"]
info_dav
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
print(info_dav["Salary"])
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
employee[["Title"]]
# Out:
#        Title
# 0    analyst
# 1    analyst
# 2    analyst
# 3    analyst
# 4  associate
# 5  associate
# 6         VP
# 7  associate
# 8         VP

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
to_find=employee[(employee["Title"]== "associate")&(employee["Salary"]>55)]
to_find
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
div_empl=employee.groupby("Years")["Salary"].mean()
div_empl
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
div_title=employee.groupby("Years")["Salary"].mean()
div_title
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
#
# * Hint : Quantiles vs Quartiles*
# In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.

# %%
sns.boxplot(data=employee, x="Years", y="Salary", palette="coolwarm", legend=True)
plt.show()
# Out:
# C:\Users\igara\AppData\Local\Temp\ipykernel_21048\3711813604.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=employee, x="Years", y="Salary", palette="coolwarm", legend=True)

# %%
def q1(data):
    Q1 = data.quantile(0.25)

    return Q1

# %%
data_series = employee["Salary"]  # replace 'ColumnName' with your specific column
Q1 = q1(data_series)
Q1
# Out:
# 35.0

# %%
def q3(data):
    Q3 = data.quantile(0.75)

    return Q3

# %%
data_series2=employee["Salary"]
Q3=q3(data_series2)
Q3
# Out:
# 60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
men=employee[employee["Gender"]=="M"]
men["Salary"].mean()
# Out:
# 50.0

# %%
wom=employee[employee["Gender"]=="F"]
wom["Salary"].mean()
# Out:
# 47.5

# %%
#There is a difference of 2.5

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
employee.groupby("Department")[["Salary","Years"]].agg(["min","mean","max"])
# Out:
#            Salary            Years
#               min   mean max   min      mean max
# Department
# HR             30  45.00  70     2  4.666667   8
# IT             30  48.75  70     1  4.500000   8
# Sales          55  55.00  55     2  2.500000   3

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
orders=pd.read_csv("C:/Users/igara/Ironhack Bootcamp/Bootcamp ironhack week4/lab-descriptive-stats-en-main/your-code/Orders.csv")

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
orders.sample(4)
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 135980      197034     553886     23132  2011      5    4    15
# 76349       117194     546367     22727  2011      3    5    11
# 388653      526717     580676     23498  2011     12    1    14
# 104190      153862     549830    84596F  2011      4    2    13
#
#                              Description  Quantity          InvoiceDate  \
# 135980  small ivory heart wall organiser         6  2011-05-19 15:53:00
# 76349          alarm clock bakelike red          4  2011-03-11 11:38:00
# 388653            classic bicycle clips          1  2011-12-05 14:39:00
# 104190      small marshmallows pink bowl         8  2011-04-12 13:01:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 135980       5.75       15648  United Kingdom         34.50
# 76349        3.75       15513  United Kingdom         15.00
# 388653       1.45       17817  United Kingdom          1.45
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
orders["UnitPrice"].mean()
# Out:
# 3.1161744805540756

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
max(orders["UnitPrice"])
# Out:
# 8142.75

# %%
min(orders["UnitPrice"])
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
spain=orders[orders["Country"]=="Spain"]
spain
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
orders["Country"].value_counts()
# Out:
# Country
# United Kingdom          354345
# Germany                   9042
# France                    8342
# EIRE                      7238
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1842
# Portugal                  1462
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     248
# Unspecified                244
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# ...

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
selected=orders[orders["Quantity"]>50]
selected
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 174            176     536386    85099C  2010     12    3     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 397720      541702     581566     23404  2011     12    5    11
# 397721      541703     581567     21417  2011     12    5    11
# 397729      541711     581567     21326  2011     12    5    11
# 397761      541746     581571     23167  2011     12    5    12
# 397882      541867     581584     20832  2011     12    5    12
#
#                                Description  Quantity          InvoiceDate  \
# 46         paper chain kit 50's christmas         80  2010-12-01 09:00:00
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
selected_2=orders[(orders["Country"]=="Spain")&(orders["Quantity"]>50)]
selected_2
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
select_0=orders[orders["amount_spent"]==0]
select_0
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
select_lunch=orders[orders["Description"].str.contains("lunch bag")]
select_lunch
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
selected_dat=orders[(orders["Description"].str.contains("lunch bag"))]
selected_dat=selected_dat[selected_dat["year"]==2011]
selected_dat
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
sp_data=orders[orders["Country"]=="Spain"]
frequency=sp_data["amount_spent"].value_counts()
pd.DataFrame(frequency)
# Out:
#               count
# amount_spent
# 15.00           186
# 17.70           122
# 19.80            99
# 17.40            86
# 10.20            76
# ...             ...
# 3.36              1
# 8.67              1
# 5.85              1
# 27.00             1
# 109.50            1
#
# [316 rows x 1 columns]

# %% [markdown]
# #### Select all orders made in the month of August

# %%
august=orders[orders["month"]==8]
august
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
coun_aug=pd.DataFrame(august["Country"].value_counts())
coun_aug
# Out:
#                  count
# Country
# United Kingdom   23105
# Germany            795
# EIRE               593
# France             569
# Netherlands        280
# Switzerland        267
# Spain              252
# Belgium            194
# Israel             171
# Channel Islands    140
# Australia          107
# Italy               95
# Austria             88
# Norway              77
# Finland             61
# Malta               55
# Portugal            41
# Sweden              40
# Unspecified         23
# Iceland             22
# Poland              17
# Denmark             16
# Canada               5

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
av_coun=pd.DataFrame(orders.groupby("Country")["amount_spent"].mean())
av_coun
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
pd.DataFrame(orders.loc[orders["UnitPrice"].idxmax()])
# Out:
#                            118352
# Unnamed: 0                 173382
# InvoiceNo                  551697
# StockCode                    POST
# year                         2011
# month                           5
# day                             2
# hour                           13
# Description               postage
# Quantity                        1
# InvoiceDate   2011-05-03 13:46:00
# UnitPrice                 8142.75
# CustomerID                  16029
# Country            United Kingdom
# amount_spent              8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
y_a=pd.DataFrame(orders.groupby("year")["amount_spent"].mean())
y_a
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
